# %% [markdown]
# # 외국인 비율과 범죄비율의 상관관계 분석

# %% [markdown]
# ### 외국인 비율 5%가 넘는 도시를 선정하여 범죄비율의 상관관계분석을 해보기로 함

# %% [markdown]
# #### 분석목표
# - 인구수 대비 외국인 비율을 파악
# - 인구수 대비 외국인 비율을 파악하여 5%가 넘는 시,군,구를 파악하여 범죄비율 파악

# %% [markdown]
# ## 데이터 정리하기

# %% [markdown]
# - 필요한 모듈 실행

# %%
import pandas as pd
import numpy as np

# %%
# 데이터 로드
crime_police = pd.read_csv('2016_crime1.csv', encoding='euc-kr', thousands=',', header= 1)
crime_police.head()
# Out:
#     -  범죄중분류 살인기수 살인미수등    강도    강간 유사강간   강제추행 기타 강간  강제추행등    방화   ...    \
# 0   계    NaN  356   558  1149  5155  583  16054          408  1502   ...
# 1  서울    NaN   46   100   260  1129  123   4667           72   286   ...
# 2  부산    NaN   29    43   137   314   28    951           30    98   ...
# 3  대구    NaN   17    12    51   197   37    632           14    68   ...
# 4  인천    NaN   20    28    88   347   47   1176           27    84   ...
#
#    특별경제범죄  마약범죄   보건범죄  환경범죄    교통범죄  노동범죄  안보범죄  선거범죄   병역범죄    기타범죄
# 0   65025  7329  14662  4349  600401  2457    81  1018  16651  260539
# 1   17109  1449   3875    58   74270   509    19   180   4120   44407
# 2    8134   963   2365   223   32944   209     6    60    662   22296
# 3    2756   334    289    11   31682    96     2    28    615   10712
# 4    3741   641    957    85   30972    80     4    64   1281   14952
#
# [5 rows x 40 columns]

# %%
crime_police = crime_police.drop(index = 0)

# %%
crime_police = crime_police.drop(columns = "범죄중분류").head()

# %%
crime_police.head()
# Out:
#     - 살인기수 살인미수등   강도    강간 유사강간  강제추행 기타 강간  강제추행등   방화   절도범죄  ...    \
# 1  서울   46   100  260  1129  123  4667           72  286  46861  ...
# 2  부산   29    43  137   314   28   951           30   98  16777  ...
# 3  대구   17    12   51   197   37   632           14   68   9171  ...
# 4  인천   20    28   88   347   47  1176           27   84  10025  ...
# 5  광주    9     8   47   170   21   488           15   38   6050  ...
#
#    특별경제범죄  마약범죄  보건범죄  환경범죄   교통범죄  노동범죄 안보범죄  선거범죄  병역범죄   기타범죄
# 1   17109  1449  3875    58  74270   509   19   180  4120  44407
# 2    8134   963  2365   223  32944   209    6    60   662  22296
# 3    2756   334   289    11  31682    96    2    28   615  10712
# 4    3741   641   957    85  30972    80    4    64  1281  14952
# 5    1616    75   249     8  22137    29    8     7   330   4809
#
# [5 rows x 39 columns]

# %%
crime_police.columns.rename()

# %%
# 구글맵 패키지
import googlemaps

# %%
# https://developers.google.com/maps/documentation/geocoding/start?hl=ko
gmaps_key = "AIzaSyAZwY2qoN3eNy-KVT-N2dEAcUB3luYcJ5g"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
gmaps.geocode('한국시청', language='ko')
# Out:
# [{'address_components': [{'long_name': '１１０',
#     'short_name': '１１０',
#     'types': ['premise']},
#    {'long_name': '세종대로',
#     'short_name': '세종대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '명동',
#     'short_name': '명동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-101',
#     'short_name': '100-101',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 명동 세종대로 110',
#   'geometry': {'location': {'lat': 37.5662952, 'lng': 126.9779451},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5676441802915,
#      'lng': 126.9792940802915},
#     'southwest': {'lat': 37.5649462197085, 'lng': 126.9765961197085}}},
#   'place_id': 'ChIJKwjLMvOifDURqPAMQqxwK-k',
#   'types': ['city_hall',
#    'establishment',
#    'local_government_office',
#    'point_of_interest']}]

# %%
# 검색 키워드 만들기 ex) XX경찰서
city_name = []
for name in crime_police ['도시명'] :
    city_name.append(str(name[:]) + '시')
city_name[2:]
# Out:
# ['서울시',
#  '부산시',
#  '대구시',
#  '인천시',
#  '광주시',
#  '대전시',
#  '울산시',
#  '세종시',
#  '고양시',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시',
#  '성남시',
#  '수원시',
#  '시흥시',
#  '안산시',
#  '안성시',
#  '안양시',
#  '양주시',
#  '여주시',
#  '오산시',
#  '용인시',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시',
#  '강릉시',
#  '동해시',
#  '삼척시',
#  '속초시',
#  '원주시',
#  '춘천시',
#  '태백시',
#  '제천시',
#  '청주시',
#  '충주시',
#  '계룡시',
#  '공주시',
#  '논산시',
#  '당진시',
#  '보령시',
#  '서산시',
#  '아산시',
#  '천안시',
#  '군산시',
#  '김제시',
#  '남원시',
#  '익산시',
#  '전주시',
#  '정읍시',
#  '광양시',
#  '나주시',
#  '목포시',
#  '순천시',
#  '여수시',
#  '경산시',
#  '경주시',
#  '구미시',
#  '김천시',
#  '문경시',
#  '상주시',
#  '안동시',
#  '영주시',
#  '영천시',
#  '포항시',
#  '거제시',
#  '김해시',
#  '밀양시',
#  '사천시',
#  '양산시',
#  '진주시',
#  '창원시',
#  '통영시',
#  '서귀포시',
#  '제주시']

# %%
crime_police.loc[3,'도시명']
# Out:
# '부산'

# %%
# 데이터 내 모든 경찰서의 주소 얻기
city_address = []
city_lat = []
city_lng = []

for name in city_name[2:]: # 조금 전 작업한 station_name에서
    tmp = gmaps.geocode(name, language='ko') # 경찰서이름을 넣고, geocode 정보를 가져와 tmp에 저장한다.
    city_address.append(tmp[0].get("formatted_address")) # tmp[0]번째의 'formatted_address'를 가져와 station_address에 저장한다.
    
    tmp_loc = tmp[0].get("geometry") # tmp[0]번째의 'geometry' 정보를 tmp_loc에 저장한다.

    city_lat.append(tmp_loc['location']['lat']) # tmp_loc의 'location' 부분의 'lat'를 station_lat에 추가한다.
    city_lng.append(tmp_loc['location']['lng']) # tmp_loc의 'location' 부분의 'lng'를 station_lng에 추가한다.
    
    print(name + '-->' + tmp[0].get("formatted_address")) # 검색한 이름과 추가된 정보를 --> 로 구분하여 표현해 준다.
# Out:
# 서울시-->대한민국 서울특별시
# 부산시-->대한민국 부산광역시
# 대구시-->대한민국 대구광역시
# 인천시-->대한민국 인천광역시
# 광주시-->대한민국 광주광역시
# 대전시-->대한민국 대전광역시
# 울산시-->대한민국 울산광역시
# 통영시-->대한민국 경상남도 통영시
# 서귀포시-->대한민국 제주특별자치도 서귀포시
# 제주시-->대한민국 제주특별자치도 제주시

# %%
# 주소 확인
city_address[:5]
# Out:
# ['대한민국 서울특별시', '대한민국 부산광역시', '대한민국 대구광역시', '대한민국 인천광역시', '대한민국 광주광역시']

# %%
# 경도 확인
city_lng[:5]
# Out:
# [126.9779692, 129.0756416, 128.601445, 126.7052062, 126.8526012]

# %%
# 위도 확인
city_lat[:5]
# Out:
# [37.566535, 35.1795543, 35.8714354, 37.4562557, 35.1595454]

# %%
foreigner_korea = pd.read_csv('2016_foreigner1.csv', encoding='euc-kr')
foreigner_korea.head()
# Out:
#       구분  총인구\n('16.11.1)\n(A)  비율\n(B/A)    합계(B) Unnamed: 4 Unnamed: 5
# 0    NaN                   NaN        NaN      NaN        NaN        NaN
# 1    NaN                   NaN        NaN        계          남          여
# 2     전국            51269554.0      0.034  1764664     946561     818103
# 3  서울특별시             9805506.0      0.041   404037     189361     214676
# 4  부산광역시             3440484.0      0.017    59872      31901      27971

# %%
foreigner_korea.rename(columns={foreigner_korea.columns[1]: '총인구', foreigner_korea.columns[0]: '시별',
                         foreigner_korea.columns[2]: '외국인비율',
                         foreigner_korea.columns[3]: '합계',
                         foreigner_korea.columns[4]: '외국인남성',
                         foreigner_korea.columns[5]: '외국인여성',
                        }, inplace=True)
foreigner_korea
# Out:
#           시별         총인구  외국인비율       합계   외국인남성   외국인여성
# 0        NaN         NaN    NaN      NaN     NaN     NaN
# 1        NaN         NaN    NaN        계       남       여
# 2         전국  51269554.0  0.034  1764664  946561  818103
# 3      서울특별시   9805506.0  0.041   404037  189361  214676
# 4      부산광역시   3440484.0  0.017    59872   31901   27971
# 5      대구광역시   2461002.0  0.016    40251   21407   18844
# 6      인천광역시   2913024.0  0.032    94670   50587   44083
# 7      광주광역시   1501557.0  0.021    31162   15945   15217
# 8      대전광역시   1535445.0  0.017    26656   11817   14839
# 9      울산광역시   1166033.0  0.031    35929   20768   15161
# 10   세종특별자치시    242507.0  0.025     6084    3351    2733
# 11       수원시   1207032.0  0.045    54284   27310   26974
# 12       성남시    951518.0  0.031    29199   13686   15513
# 13      의정부시    424722.0  0.017     7248    3144    4104
# 14       안양시    582049.0  0.022    12568    5811    6757
# 15       부천시    844043.0  0.039    33081   15798   17283
# 16       광명시    334361.0  0.031    10269    4681    5588
# 17       평택시    472254.0  0.061    28999   16512   12487
# 18      동두천시     98625.0  0.050     4931    2456    2475
# 19       안산시    743072.0  0.107    79752   43801   35951
# 20       고양시    999098.0  0.021    21340   10412   10928
# 21       과천시     60923.0  0.010      581     273     308
# 22       구리시    183905.0  0.014     2527    1076    1451
# 23      남양주시    641589.0  0.018    11545    6213    5332
# 24       오산시    215478.0  0.062    13274    6479    6795
# 25       시흥시    429321.0  0.106    45668   25768   19900
# 26       군포시    284301.0  0.039    11113    5482    5631
# 27       의왕시    153629.0  0.015     2281    1165    1116
# 28       하남시    195422.0  0.017     3351    1722    1629
# 29       용인시    982590.0  0.027    26317   14244   12073
# ..       ...         ...    ...      ...     ...     ...
# 72       군산시    276394.0  0.031     8498    4985    3513
# 0   -  범죄중분류  살인기수  살인미수등     강도     강간   유사강간   강제추행  기타 강간  강제추행등     방화
# 1   계    NaN   356    558   1149   5155    583  16054           408   1502
# 2  서울    NaN    46    100    260   1129    123   4667            72    286
# 3  부산    NaN    29     43    137    314     28    951            30     98
# 4  대구    NaN    17     12     51    197     37    632            14     68
#
#                   ...                   마약범죄   보건범죄  환경범죄    교통범죄  노동범죄  안보범죄  \
# 0                 ...                   마약범죄   보건범죄  환경범죄    교통범죄  노동범죄  안보범죄
# 1                 ...                   7329  14662  4349  600401  2457    81
# 2                 ...                   1449   3875    58   74270   509    19
# 3                 ...                    963   2365   223   32944   209     6
# 4                 ...                    334    289    11   31682    96     2
#
#    선거범죄   병역범죄    기타범죄                               강력범죄합계
# 0  선거범죄   병역범죄    기타범죄  살인기수살인미수등강도강간유사강간강제추행기타 강간  강제추행등방화
# 1  1018  16651  260539        35655811495155583160544081502
# 2   180   4120   44407             461002601129123466772286
# 3    60    662   22296                  2943137314289513098
# 4    28    615   10712                   171251197376321468
#
# [5 rows x 41 columns]

# %%
crime_polce=crime_police.dropna(axis=1)

# %%
pd.to_numeric(crime_police.iloc[:,1:], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-d3761a1a86e9> in <module>()
# ----> 1 pd.to_numeric(crime_police.iloc[:,1:], errors='coerce')
#
# D:\miniconda\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     118         values = np.array([arg], dtype='O')
#     119     elif getattr(arg, 'ndim', 1) > 1:
# --> 120         raise TypeError('arg must be a list, tuple, 1-d array, or Series')
#     121     else:
#     122         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
crime_police.to_numeric
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-645ccb372b55> in <module>()
# ----> 1 crime_police.to_numeric
#
# D:\miniconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numeric'

# %%
crime_police["범죄 합계"] = crime_police.sum(crime_police.columns[2:])
crime_police
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f91c690b569c> in <module>()
# ----> 1 crime_police["범죄 합계"] = crime_police.sum(crime_police.columns[2:])
#       2 crime_police
#
# D:\miniconda\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    7293                                       skipna=skipna, min_count=min_count)
#    7294         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 7295                             numeric_only=numeric_only, min_count=min_count)
#    7296
#    7297     return set_function_name(stat_func, name, cls)
#
# D:\miniconda\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    5693     def _reduce(self, op, name, axis=0, skipna=True, numeric_only=None,
#    5694                 filter_type=None, **kwds):
# -> 5695         axis = self._get_axis_number(axis)
#    5696
#    5697         def f(x):
#
# D:\miniconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     345
#     346     def _get_axis_number(self, axis):
# --> 347         axis = self._AXIS_ALIASES.get(axis, axis)
#     348         if is_integer(axis):
#     349             if axis in self._AXIS_NAMES:
#
# D:\miniconda\lib\site-packages\pandas\core\indexes\base.py in __hash__(self)
#    1719
#    1720     def __hash__(self):
# -> 1721         raise TypeError("unhashable type: %r" % type(self).__name__)
#    1722
#    1723     def __setitem__(self, key, value):
#
# TypeError: unhashable type: 'Index'

# %%
crime_police["범죄합계"] = crime_police.sum(crime_police.columns[2:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-95f5e5b0e825> in <module>()
# ----> 1 crime_police["범죄합계"] = crime_police.sum(crime_police.columns[2:])
#
# D:\miniconda\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    7293                                       skipna=skipna, min_count=min_count)
#    7294         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 7295                             numeric_only=numeric_only, min_count=min_count)
#    7296
#    7297     return set_function_name(stat_func, name, cls)
#
# D:\miniconda\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    5693     def _reduce(self, op, name, axis=0, skipna=True, numeric_only=None,
#    5694                 filter_type=None, **kwds):
# -> 5695         axis = self._get_axis_number(axis)
#    5696
#    5697         def f(x):
#
# D:\miniconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     345
#     346     def _get_axis_number(self, axis):
# --> 347         axis = self._AXIS_ALIASES.get(axis, axis)
#     348         if is_integer(axis):
#     349             if axis in self._AXIS_NAMES:
#
# D:\miniconda\lib\site-packages\pandas\core\indexes\base.py in __hash__(self)
#    1719
#    1720     def __hash__(self):
# -> 1721         raise TypeError("unhashable type: %r" % type(self).__name__)
#    1722
#    1723     def __setitem__(self, key, value):
#
# TypeError: unhashable type: 'Index'

# %%
crime = crime_police.drop(crime_police.columns[10:], axis=1)
crime
# Out:
#     도시명  범죄대분류  강력범죄 강력범죄.1 강력범죄.2 강력범죄.3 강력범죄.4  강력범죄.5        강력범죄.6 강력범죄.7
# 0     -  범죄중분류  살인기수  살인미수등     강도     강간   유사강간    강제추행  기타 강간  강제추행등     방화
# 1     계    NaN   356    558  1,149  5,155    583  16,054           408  1,502
# 2    서울    NaN    46    100    260  1,129    123   4,667            72    286
# 3    부산    NaN    29     43    137    314     28     951            30     98
# 4    대구    NaN    17     12     51    197     37     632            14     68
# 5    인천    NaN    20     28     88    347     47   1,176            27     84
# 6    광주    NaN     9      8     47    170     21     488            15     38
# 7    대전    NaN    16      9     35    171     14     420            15     44
# 8    울산    NaN     7     15     33    112     16     293             9     38
# 9    세종    NaN     1      1      3     10      1      40             -      2
# 10   고양    NaN     6      5     11     83      4     247             4     22
# 11   과천    NaN     -      1      1      -      1      20             -      2
# 12   광명    NaN     1      1      4     32      3      92             2      8
# 13   광주    NaN     3     10      4     16      2      60             5      4
# 14   구리    NaN     1      5      1     30      3      83             2     11
# 15   군포    NaN     -      1      3     18      2      66             2      4
# 16   김포    NaN     2      2      6     20      3      92             3      6
# 17  남양주    NaN     3      7      9     60      2     165             2     18
# 18  동두천    NaN     1      -      -      6      -      37             3      6
# 19   부천    NaN     6     11     17    108     15     339            10     24
# 20   성남    NaN     5      4     17    114     10     348             6     21
# 21   수원    NaN    10     19     26    124     24     408            14     29
# 22   시흥    NaN     8      7      9     57      4     120             1     15
# 23   안산    NaN     4     20     19     98      8     307             3     32
# 24   안성    NaN     2      4      3     15      2      55             1      4
# 25   안양    NaN     6      4      7     45      4     220             3      9
# 26   양주    NaN     -      2      2     27      1      32             2      5
# 27   여주    NaN     2      5      -     14      1      45             -      3
# 28   오산    NaN     1      4      1     20      3      67             1      6
# 29   용인    NaN     2     13      5     38     10     184             3     12
# ..  ...    ...   ...    ...    ...    ...    ...     ...           ...    ...
# 57   김제    NaN     -      1      -      6      -      14             2      1
# 58   남원    NaN     -      -      2      6      1      17             -      2
# 59   익산    NaN     4      5     15     25      4      64             3     13
# 60   전주    NaN     3      7     12     62      7     165             6     12
# 61   정읍    NaN     -      3      1     11      4      22             1      2
# 62   광양    NaN     -      2      5     21      1      25             1      4
# 63   나주    NaN     -      -      -      4      -       6             -      2
# 64   목포    NaN     1      4      5     33      5      97             5     15
# 65   순천    NaN     3      2      4     30      1      72             3      7
# 66   여수    NaN     3      -      6     20      2      67             -      8
# 67   경산    NaN     2      1      6     36      2      50             -      3
# 68   경주    NaN     3      3      6     21      1      60             1     13
# 69   구미    NaN     1      4     15     35      4      72             1      9
# 70   김천    NaN     1      -      1     15      -      17             1      5
# 71   문경    NaN     -      -      -      9      -      12             -      2
# 72   상주    NaN     -      1      2      6      -      17             1      3
# 73   안동    NaN     1      1      1     13      -      44             -      5
# 74   영주    NaN     1      1      1      3      1      16             -      2
# 75   영천    NaN     2      1      1      9      -      13             -      6
# 76   포항    NaN     5      6      7     57      7      97             3     10
# 77   거제    NaN     2      -      5     18      4      73             2     10
# 78   김해    NaN     5      4     10     31      6     111             4     17
# 79   밀양    NaN     2      -      4      8      -      12             -      5
# 80   사천    NaN     -      3      1      5      2      25             4      2
# 81   양산    NaN     3      1      7     31      4      76             1      5
# 82   진주    NaN     2      3      6     32      1      74             3      6
# 83   창원    NaN     3     15     26     68      7     202             7     29
# 84   통영    NaN     -      3      1     15      1      27             3      -
# 85  서귀포    NaN     -      1      1     16      3      95             1     11
# 86   제주    NaN     4     11     24     68     13     223             7     15
#
# [87 rows x 10 columns]

# %%
crime_police.head()
# Out:
#   도시명  범죄대분류 강력범죄.2 강력범죄.3 강력범죄.4  강력범죄.5        강력범죄.6 강력범죄.7   강력범죄   \
# 0   -  범죄중분류     강도     강간   유사강간    강제추행  기타 강간  강제추행등     방화      합계
# 1   계    NaN  1,149  5,155    583  16,054           408  1,502  25,765
# 2  서울    NaN    260  1,129    123   4,667            72    286   6,683
# 3  부산    NaN    137    314     28     951            30     98   1,630
# 4  대구    NaN     51    197     37     632            14     68   1,028
#
#       절도범죄   ...     특별경제범죄   마약범죄    보건범죄   환경범죄     교통범죄   노동범죄  안보범죄  \
# 0     절도범죄   ...     특별경제범죄   마약범죄    보건범죄   환경범죄     교통범죄   노동범죄  안보범죄
# 1  203,037   ...     65,025  7,329  14,662  4,349  600,401  2,457    81
# 2   46,861   ...     17,109  1,449   3,875     58   74,270    509    19
# 3   16,777   ...      8,134    963   2,365    223   32,944    209     6
# 4    9,171   ...      2,756    334     289     11   31,682     96     2
#
#     선거범죄    병역범죄     기타범죄
# 0   선거범죄    병역범죄     기타범죄
# 1  1,018  16,651  260,539
# 2    180   4,120   44,407
# 3     60     662   22,296
# 4     28     615   10,712
#
# [5 rows x 39 columns]
