# %%
#http://pinkwink.kr/959 엑셀 불러오는법 (xlsx)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
y_per=pd.read_excel('The_Performance(13-17).xlsx')
y_per.head(6)
# Out:
#     연도  총 수송인원(천명)  운수수입(백만원)  계(무임수송인원)  노인(천명)  장애인(천명)  유공자(천명)  기본요금(원)
# 0  '13     2619529    1538879     240321  185426    51158     3737     1050
# 1  '14     2660907    1567937     248143  194791    49719     3633     1050
# 2  '15     2640527    1667841     249942  198699    47782     3461     1250
# 3  '16     2856452    1790798     253566  203837    46349     3380     1250
# 4  '17     2654317    1687841     258376  210157    44955     3265     1250

# %%
# 여기서 필요한 데이터인 노인 무임승차 인원에 대한 정보만 가져오도록 하자.
table=pd.read_excel('The_Performance(13-17).xlsx',
                   header =0,
                   index_col=0,
                   usecols="A,E",
                   convert_float = True)

# %%
table.head()
# Out:
#      노인(천명)
# 연도
# '13  185426
# '14  194791
# '15  198699
# '16  203837
# '17  210157

# %%
# %matplotlib inline
import pandas as pd                
import matplotlib as mpl          
import matplotlib.pyplot as plt   
 

T = table
T
# Out:
#      노인(천명)
# 연도
# '13  185426
# '14  194791
# '15  198699
# '16  203837
# '17  210157

# %%
>>> T.loc["'13"]
# Out:
# 노인(천명)    185426
# Name: '13, dtype: int64

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)
 
ax = T.plot(kind='bar', title='노인 무임승차자의 변화추이', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('연도', fontsize=12)        
ax.set_ylabel('노인 무임승차자', fontsize=12)    
ax.set_ylim(180000,215000)
ax.legend(['노인 무임승차자'], fontsize=12)

# %%
y_fin=pd.read_excel('Seoul_financial.xlsx')
y_fin.head(6)
# Out:
#      연도         당기순손익
# 0  2013 -417190655022
# 1  2014 -424530357000
# 2  2015 -413708634691
# 3  2016 -385048147441
# 4  2017 -525362473465

# %%
y_fin.set_index(keys="연도", inplace=True)

# %%
col = []
for i in y_fin.columns:
    col.append(i.split()[0][:-1]+"."+i.split()[1][:-1])
col[:5]
y_fin.columns = col
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-157c1332f4ca> in <module>()
#       1 col = []
#       2 for i in y_fin.columns:
# ----> 3     col.append(i.split()[0][:-1]+"."+i.split()[1][:-1])
#       4 col[:5]
#       5 y_fin.columns = col
#
# IndexError: list index out of range

# %%
연도선택 = [2013, 2014, 2015, 2016, 2017] 

xs0 = y_fin.columns # 연도
xs0 = pd.to_datetime(xs0)## 가로를 연도로 보기 위해
plt.figure(figsize=(15,15))

for i in range(len(연도선택)):
    plt.plot(xs0, list(y_fin.loc[연도선택[i],:]), marker= '.', label=연도선택[i]) # 녹색 실선


plt.legend(bbox_to_anchor=(1, 1), loc=0,borderaxespad=0.) # 범례 그리기, loc=9 ; top center를 의미
plt.ylabel('당기순손익')
plt.xlabel('연도')
plt.title('당기순손익의 변화')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Miniconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6c3b49d82cec> in <module>()
#       2
#       3 xs0 = y_fin.columns # 연도
# ----> 4 xs0 = pd.to_datetime(xs0)## 가로를 연도로 보기 위해
#       5 plt.figure(figsize=(15,15))
#       6
#
# ...

# %%
연도 = [당기순손익]

plt.figure(figsize=(15,10))
for i in range(len(당기순손익)):
    plt.plot(xs1, list(data1.loc[당기순손익[i],:]), marker= '.', label=당기순손익[i]) # 녹색 실선

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.1,fontsize=20) # 범례 그리기, loc=9 ; top center를 의미
plt.ylabel('당기순손익',size=15)
plt.xlabel('연도',size=15)
plt.title('당기순손익',size=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1a743d70dc12> in <module>()
# ----> 1 연도 = [당기순손익]
#       2
#       3 plt.figure(figsize=(15,10))
#       4 for i in range(len(당기순손익)):
#       5     plt.plot(xs1, list(data1.loc[당기순손익[i],:]), marker= '.', label=당기순손익[i]) # 녹색 실선
#
# NameError: name '당기순손익' is not defined

# %% [markdown]
# ### 따라서 매스컴의 보도가 일리가 있는 것으로 확인됨
#
# ### 그렇다면 현재 노인인구(65세 이상)의 변화추이는 어떻게 되는가?

# %%
y_pop=pd.read_excel('Seoul_Pop_detail(13-17).xlsx')
y_pop.head(6)
# Out:
#      기간     65세    66세    67세    68세    69세    70세    71세    72세    73세  \
# 0  2013   96948  99381  80330  71025  71913  70798  84397  67721  58019
# 1  2014   96354  95181  97469  78719  69544  70375  69173  82269  65960
# 2  2015   93155  94226  93095  95131  76905  67767  68503  67211  79812
# 3  2016   81961  91255  92072  90835  92833  75089  65982  66730  65391
# 4  2017  114400  80233  89224  89871  88753  90591  73185  64285  64933
#
#      74세    75세    76세    77세    78세    79세  80~89세  90~99세  100세 이상
# 0  57326  50202  45327  41164  38703  32792  158807   22882      603
# 1  56411  55563  48596  43781  39642  37078  171502   24165      671
# 2  64075  54571  53650  46780  42051  37947  192801   29719     5037
# 3  77388  62084  52772  51775  44952  40378  207716   31211     5475
# 4  63515  74898  60021  50860  49861  43160  223113   33479     5519

# %% [markdown]
# ### 이렇게 확인해서는 연도별 노인인구 수를 확인하기 어려우므로 연도별로 다 더해보자

# %%
y_pop["노인인구합"] = (y_pop['65세']+y_pop['66세']+y_pop['67세']+y_pop['68세']+y_pop['69세']+y_pop['70세']+y_pop['71세']+y_pop['72세']+y_pop['73세']+y_pop['74세']+y_pop['75세']+y_pop['76세']+y_pop['77세']+y_pop['78세']+y_pop['79세']+y_pop['80~89세']+y_pop['90~99세']+y_pop['100세 이상'])

# %%
y_pop.head(6)
# Out:
#      기간     65세    66세    67세    68세    69세    70세    71세    72세    73세  \
# 0  2013   96948  99381  80330  71025  71913  70798  84397  67721  58019
# 1  2014   96354  95181  97469  78719  69544  70375  69173  82269  65960
# 2  2015   93155  94226  93095  95131  76905  67767  68503  67211  79812
# 3  2016   81961  91255  92072  90835  92833  75089  65982  66730  65391
# 4  2017  114400  80233  89224  89871  88753  90591  73185  64285  64933
#
#      74세    75세    76세    77세    78세    79세  80~89세  90~99세  100세 이상    노인인구합
# 0  57326  50202  45327  41164  38703  32792  158807   22882      603  1148338
# 1  56411  55563  48596  43781  39642  37078  171502   24165      671  1202453
# 2  64075  54571  53650  46780  42051  37947  192801   29719     5037  1262436
# 3  77388  62084  52772  51775  44952  40378  207716   31211     5475  1295899
# 4  63515  74898  60021  50860  49861  43160  223113   33479     5519  1359901

# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
frame =DataFrame(y_pop)
frame
# Out:
#      기간     65세    66세    67세    68세    69세    70세    71세    72세    73세  \
# 0  2013   96948  99381  80330  71025  71913  70798  84397  67721  58019
# 1  2014   96354  95181  97469  78719  69544  70375  69173  82269  65960
# 2  2015   93155  94226  93095  95131  76905  67767  68503  67211  79812
# 3  2016   81961  91255  92072  90835  92833  75089  65982  66730  65391
# 4  2017  114400  80233  89224  89871  88753  90591  73185  64285  64933
#
#      74세    75세    76세    77세    78세    79세  80~89세  90~99세  100세 이상    노인인구합
# 0  57326  50202  45327  41164  38703  32792  158807   22882      603  1148338
# 1  56411  55563  48596  43781  39642  37078  171502   24165      671  1202453
# 2  64075  54571  53650  46780  42051  37947  192801   29719     5037  1262436
# 3  77388  62084  52772  51775  44952  40378  207716   31211     5475  1295899
# 4  63515  74898  60021  50860  49861  43160  223113   33479     5519  1359901

# %%
frame =DataFrame(y_pop, columns = ['기간', '노인인구합'])

# %%
frame.head()
# Out:
#      기간    노인인구합
# 0  2013  1148338
# 1  2014  1202453
# 2  2015  1262436
# 3  2016  1295899
# 4  2017  1359901

# %%
table.head()
# Out:
#      노인(천명)
# 연도
# '13  185426
# '14  194791
# '15  198699
# '16  203837
# '17  210157
