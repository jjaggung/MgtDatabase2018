# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")
# %matplotlib inline

# %%
data = pd.read_excel("foreign_investment.xlsx")
data
# Out:
#       항목  신고건수 (건)  신규법인수 (개)  신고금액 (천달러)  송금횟수 (건)  투자금액 (천달러)
# 0   2000      3952       2119     6236634      5653     5286426
# 1   2001      4063       2181     6584775      6666     5365285
# 2   2002      4799       2521     6706217      8166     4056808
# 3   2003      5461       2824     6518741      9471     4770629
# 4   2004      7198       3795     8990692     13346     6552573
# 5   2005      8890       4450     9805613     16484     7282137
# 6   2006     10179       5207    19378185     19030    11876228
# 7   2007     11965       5687    30415904     21452    22687030
# 8   2008     10639       4037    36911473     19270    24021318
# 9   2009      7537       2474    30968218     13731    20709847
# 10  2010      8120       2889    34437234     13862    24637846
# 11  2011      7921       2755    45737888     13555    29082887
# 12  2012      7676       2539    39652738     12767    28540481
# 13  2013      8062       2817    35634888     12720    30192739
# ...

# %%
data = data.set_index(data.항목)

# %%
ax = sns.tsplot(data=data, )
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-84-bc6184d4ffdc> in <module>()
# ----> 1 ax = sns.tsplot(data=data)
#
# E:\Programs\Anaconda3\lib\site-packages\seaborn\timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     329
#     330     # Pad the sides of the plot only when not interpolating
# --> 331     ax.set_xlim(x.min(), x.max())
#     332     x_diff = x[1] - x[0]
#     333     if not interpolate:
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %%
data = data.melt('X_Axis', var_name='cols',  value_name='vals')
g = sns.factorplot(x="X_Axis", y="vals", hue='cols', data=df)

# %%
df = pd.DataFrame({'X_Axis':[1,3,5,7,10,20],
                   'col_2':[.4,.5,.4,.5,.5,.4],
                   'col_3':[.7,.8,.9,.4,.2,.3],
                   'col_4':[.1,.3,.5,.7,.1,.0],
                   'col_5':[.5,.3,.6,.9,.2,.4]})

# %%
df
# Out:
#    X_Axis  col_2  col_3  col_4  col_5
# 0       1    0.4    0.7    0.1    0.5
# 1       3    0.5    0.8    0.3    0.3
# 2       5    0.4    0.9    0.5    0.6
# 3       7    0.5    0.4    0.7    0.9
# 4      10    0.5    0.2    0.1    0.2
# 5      20    0.4    0.3    0.0    0.4

# %%
df.iloc[:,0] = [2011, 2012, 2013, 2014, 2015, 2016]

# %%
df
# Out:
#    X_Axis  col_2  col_3  col_4  col_5
# 0    2011    0.4    0.7    0.1    0.5
# 1    2012    0.5    0.8    0.3    0.3
# 2    2013    0.4    0.9    0.5    0.6
# 3    2014    0.5    0.4    0.7    0.9
# 4    2015    0.5    0.2    0.1    0.2
# 5    2016    0.4    0.3    0.0    0.4

# %%
df = df.melt('X_Axis', var_name='cols',  value_name='vals')
g = sns.factorplot(x="X_Axis", y="vals", hue='cols', data=df)
# Out:
# E:\Programs\Anaconda3\lib\site-packages\seaborn\categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
g = sns.factorplot(x="항목", y="vals", hue='cols', data=data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-f718e2b6d5b2> in <module>()
#       1 plt.hist(data.iloc[:,1])
# ----> 2 sns.rugplot(df.x);
#
# E:\Programs\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'x'

# %%
data2d = {'date': ['2014-05-01 18:47:05.069722', '2014-05-01 18:47:05.119994', '2014-05-02 18:47:05.178768', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.280592', '2014-05-03 18:47:05.332662', '2014-05-03 18:47:05.385109', '2014-05-04 18:47:05.436523', '2014-05-04 18:47:05.486877'], 
        'deaths_regiment_1': [34, 43, 14, 15, 15, 14, 31, 25, 62, 41],
        'deaths_regiment_2': [52, 66, 78, 15, 15, 5, 25, 25, 86, 1],
        'deaths_regiment_3': [13, 73, 82, 58, 52, 87, 26, 5, 56, 75],
        'deaths_regiment_4': [44, 75, 26, 15, 15, 14, 54, 25, 24, 72],
        'deaths_regiment_5': [25, 24, 25, 15, 57, 68, 21, 27, 62, 5],
        'deaths_regiment_6': [84, 84, 26, 15, 15, 14, 26, 25, 62, 24],
        'deaths_regiment_7': [46, 57, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data2d, columns = ['date', 'battle_deaths', 'deaths_regiment_1', 'deaths_regiment_2',
                                   'deaths_regiment_3', 'deaths_regiment_4', 'deaths_regiment_5',
                                   'deaths_regiment_6', 'deaths_regiment_7'])
df = df.set_index(df.date)

# %%
df
# Out:
#                                                   date battle_deaths  \
# date
# 2014-05-01 18:47:05.069722  2014-05-01 18:47:05.069722           NaN
# 2014-05-01 18:47:05.119994  2014-05-01 18:47:05.119994           NaN
# 2014-05-02 18:47:05.178768  2014-05-02 18:47:05.178768           NaN
# 2014-05-02 18:47:05.230071  2014-05-02 18:47:05.230071           NaN
# 2014-05-02 18:47:05.230071  2014-05-02 18:47:05.230071           NaN
# 2014-05-02 18:47:05.280592  2014-05-02 18:47:05.280592           NaN
# 2014-05-03 18:47:05.332662  2014-05-03 18:47:05.332662           NaN
# 2014-05-03 18:47:05.385109  2014-05-03 18:47:05.385109           NaN
# 2014-05-04 18:47:05.436523  2014-05-04 18:47:05.436523           NaN
# 2014-05-04 18:47:05.486877  2014-05-04 18:47:05.486877           NaN
#
#                             deaths_regiment_1  deaths_regiment_2  \
# date
# 2014-05-01 18:47:05.069722                 34                 52
# ...

# %%
sns.tsplot([df.deaths_regiment_1, df.deaths_regiment_2, df.deaths_regiment_3, df.deaths_regiment_4,
            df.deaths_regiment_5, df.deaths_regiment_6, df.deaths_regiment_7], color="indianred")

# %%
# Load the long-form example gammas dataset
gammas = sns.load_dataset("gammas", engine="python")

# Plot the response with standard error
sns.tsplot(data=gammas, time="timepoint", unit="subject",
           condition="ROI", value="BOLD signal")

# %%
gammas
# Out:
#       timepoint  ROI  subject  BOLD signal
# 0           0.0  IPS        0     0.513433
# 1           0.0  IPS        1    -0.414368
# 2           0.0  IPS        2     0.214695
# 3           0.0  IPS        3     0.814809
# 4           0.0  IPS        4    -0.894992
# 5           0.0  IPS        5    -0.073709
# 6           0.0  IPS        6     3.542734
# 7           0.0  IPS        7     0.080169
# 8           0.0  IPS        8     1.547083
# 9           0.0  IPS        9     2.827153
# 10          0.0  IPS       10     2.611358
# 11          0.0  IPS       11    -0.313132
# 12          0.0  IPS       12     3.773421
# 13          0.0  IPS       13     4.829915
# 14          0.0  IPS       14     2.891340
# 15          0.0  IPS       15    -0.736698
# 16          0.0  IPS       16     3.316986
# 17          0.0  IPS       17     3.771426
# 18          0.0  IPS       18     1.308109
# 19          0.0  IPS       19    -0.905172
# 20          0.0   AG        0     1.048369
# ...

# %%
sns.tsplot(data=data, time="항목")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-44e0c3d09c9f> in <module>()
# ----> 1 sns.tsplot(data=data, time="항목")
#
# E:\Programs\Anaconda3\lib\site-packages\seaborn\timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     278
#     279         df_c = df_c.pivot(unit, time, value)
# --> 280         x = df_c.columns.values.astype(np.float)
#     281
#     282         # Bootstrap the data for confidence intervals
#
# ValueError: setting an array element with a sequence.

# %%
sns.factorplot(x="항목", hue="")

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# 5            5   2  low fat     93  30 min     rest
# 6            6   3  low fat     97   1 min     rest
# 7            7   3  low fat     97  15 min     rest
# 8            8   3  low fat     94  30 min     rest
# 9            9   4  low fat     80   1 min     rest
# 10          10   4  low fat     82  15 min     rest
# 11          11   4  low fat     83  30 min     rest
# 12          12   5  low fat     91   1 min     rest
# 13          13   5  low fat     92  15 min     rest
# 14          14   5  low fat     91  30 min     rest
# 15          15   6   no fat     83   1 min     rest
# 16          16   6   no fat     83  15 min     rest
# ...

# %%
sns.set(style="whitegrid")

# Load the example exercise dataset
df = sns.load_dataset("exercise", engine="python")

# Draw a pointplot to show pulse as a function of three categorical factors
g = sns.factorplot(x="time", y="pulse", hue="kind", col="diet", data=df,
                   capsize=.2, palette="YlGnBu_d", size=6, aspect=.75)
g.despine(left=True)
# Out:
# E:\Programs\Anaconda3\lib\site-packages\seaborn\categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
df = sns.load_dataset("exercise")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-eedff9c5bf64> in <module>()
# ----> 1 df = sns.load_dataset("exercise")
#
# E:\Programs\Anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     425         full_path = cache_path
#     426
# --> 427     df = pd.read_csv(full_path, **kws)
#     428     if df.iloc[-1].isnull().all():
#     429         df = df.iloc[:-1]
#
# ...
